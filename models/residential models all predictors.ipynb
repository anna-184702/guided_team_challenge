# %% [markdown]
# # Residential models - model selection

# %%
from model_builder import *

# %%
# Set the model CV search conditions
unique_depths = [5, 7, 9, 12, 15] #, 12, 15, 20]
unique_n_estimators = [10, 50, 100, 150, 200, 250, 300, 350, 400]

# %% [markdown]
# ### Electric cooling

# %%
predictors, targets = get_targets_predictors('cooling', 'elec', res = True)
gscv_elec = grid_search_xgbr(predictors, targets.values.ravel(), unique_depths, unique_n_estimators)
# Out:
# Fitting 2 folds for each of 45 candidates, totalling 90 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=0.927, total=   0.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=1.116, total=   0.7s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=0.916, total=   3.1s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.5s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=1.071, total=   4.5s
# ...

# %%
model = RandomForestRegressor(max_depth = 4, n_estimators = 75)
x_train, x_test, y_train, y_test = train_test_split(predictors, targets, test_size = 0.2)
model.fit(x_train, y_train)
preds = model.predict(x_test)
