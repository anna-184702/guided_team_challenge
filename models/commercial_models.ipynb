# %% [markdown]
# # Commercial models - model selection

# %%
from model_builder import *

# %%
# Set the model CV search conditions
unique_depths = [5, 7, 9, 12, 15] #, 12, 15, 20]
unique_n_estimators = [10, 50, 100, 150, 200, 250, 300, 350, 400]

# %% [markdown]
# ### Electric heating

# %%
predictors, targets = get_targets_predictors('heating', 'elec')
gscv_elec = grid_search_xgbr(predictors, targets.values.ravel(), unique_depths, unique_n_estimators)
# Out:
# Fitting 2 folds for each of 45 candidates, totalling 90 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=1.479, total=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=2.975, total=   0.1s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=1.452, total=   0.4s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.6s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=3.005, total=   0.4s
# ...

# %%
plot_gs_results(gscv_elec, unique_depths, unique_n_estimators)

# %% [markdown]
# ### District heat heating

# %%
predictors, targets = get_targets_predictors('heating', 'dh')
gscv_dh = grid_search_xgbr(predictors, targets.values.ravel(), unique_depths, unique_n_estimators)
# Out:
# Fitting 2 folds for each of 45 candidates, totalling 90 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ....... max_depth=5, n_estimators=10, score=20.814, total=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ....... max_depth=5, n_estimators=10, score=32.906, total=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ....... max_depth=5, n_estimators=50, score=16.566, total=   0.2s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ....... max_depth=5, n_estimators=50, score=32.145, total=   0.2s
# ...

# %%
plot_gs_results(gscv_dh, unique_depths, unique_n_estimators)

# %% [markdown]
# ### Natural gas heating

# %%
predictors, targets = get_targets_predictors('heating', 'ng')
gscv_ng = grid_search_xgbr(predictors, targets.values.ravel(), unique_depths, unique_n_estimators)
# Out:
# Fitting 2 folds for each of 45 candidates, totalling 90 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=0.766, total=   0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=1.716, total=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=0.602, total=   0.2s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=1.707, total=   0.1s
# ...

# %%
plot_gs_results(gscv_ng, unique_depths, unique_n_estimators)

# %% [markdown]
# ### Electric cooling

# %%
predictors, targets = get_targets_predictors('cooling', 'elec')
gscv_cool = grid_search_xgbr(predictors, targets.values.ravel(), unique_depths, unique_n_estimators)
# Out:
# Fitting 2 folds for each of 45 candidates, totalling 90 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=4.557, total=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] max_depth=5, n_estimators=10 ....................................
# [CV] ........ max_depth=5, n_estimators=10, score=2.769, total=   0.1s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=4.535, total=   0.6s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.9s remaining:    0.0s
# [CV] max_depth=5, n_estimators=50 ....................................
# [CV] ........ max_depth=5, n_estimators=50, score=2.738, total=   0.6s
# ...

# %%
plot_gs_results(gscv_cool, unique_depths, unique_n_estimators)
